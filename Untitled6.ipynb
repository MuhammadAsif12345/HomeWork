# %% [markdown]
# #What is data science and what is the process?
# Data science is a field where data scientists manage and process unstructured data, algorithms, etc to answer question. Data scientists do not necessarily use coding in fact they can use just about anything including magnitudes if data from multiple different types of sources to answer the relevent questions. These data scientists can work in companies like google, amazon, facebook, apple etc.

# %% [markdown]
# #What is the difference between lists and tuples?
# One of the biggest difference between lists and tuples is that lists are mutable objects and tuples are immutable objects.

# %% [markdown]
# #Explain what the following major libraries do.
#
# ##Scikit learn
# This tool is used for predictive analytic, classification and various other machine learning tasks.
# ##Pandas
# This library is used for data analysis
# ##Tensorflow
# This library is used for fast numerical computing.
# ##Numpy
# This library is used to work arrays.
# ##Tkinter
# This library is used to provide a fast and easy way to create GUI applications.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/MuhammadAsif12345/HW/main/annual-enterprise-survey-2020-financial-year-provisional-csv%20(1).csv")
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
#check for nulls

df.isnull().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
#number of unique values

df.nunique()
# Out:
# Year                              8
# Industry_aggregation_NZSIOC       3
# Industry_code_NZSIOC            139
# Industry_name_NZSIOC            119
# Units                             3
# Variable_code                    39
# Variable_name                    41
# Variable_category                 3
# Value                          9295
# Industry_code_ANZSIC06          121
# dtype: int64

# %%
df.describe()
# Out:
#                Year
# count  37080.000000
# mean    2016.500000
# std        2.291319
# min     2013.000000
# 25%     2014.750000
# 50%     2016.500000
# 75%     2018.250000
# max     2020.000000

# %%
sns.catplot(data=df , kind='box' , height=4, aspect=2)

# %%
df.hist(figsize=(15, 10), bins=20, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3450d27e90>]],
#       dtype=object)
